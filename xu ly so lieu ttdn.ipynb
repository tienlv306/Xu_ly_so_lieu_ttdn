# %% [markdown]
# # Xử lý số liệu tổn thất

# %%
import pandas as pd

ttdn = pd.read_excel (r'D:\thai\table5.xlsx')

print(ttdn)
# Out:
#      Stt            Điện lực  KH 2025  Lũy kế 6T/2024  Lũy kế 6T/2025  \
# 0    1.0     Điện Lực Đà Lạt     1.21            1.31            1.14
# 1    2.0    Điện Lực Bảo Lộc     1.70            1.74            1.57
# 2    3.0  Điện Lực Đơn Dương     1.61            1.65            1.63
# 3    4.0    Điện Lực Di Linh     1.48            1.53            2.42
# 4    5.0  Điện Lực Đức Trọng     1.59            1.55            1.76
# 5    6.0     Điện Lực Lâm Hà     1.57            1.63            2.00
# 6    7.0   Điện lực Đạ Huoai     2.84            2.89            2.88
# 7    8.0     Điện lực Đạ Tẻh     1.26            1.20            1.68
# 8    9.0   Điện Lực Cát Tiên     1.18            1.44            1.83
# 9   10.0    Điện Lực Bảo Lâm     1.55            2.30            1.86
# 10  11.0  Điện Lực Lạc Dương     1.29            1.75            1.06
# 11  12.0   Điện Lực Đam Rông     2.02            1.92            1.46
# 12   NaN           Tổng cộng     1.60            1.68            1.75
#
#     So sánh cùng kỳ  So sánh KH
# 0             -0.17       -0.07
# 1             -0.17       -0.13
# 2             -0.02        0.02
# 3              0.89        0.94
# 4              0.21        0.17
# 5              0.37        0.43
# 6             -0.01        0.04
# 7              0.48        0.42
# 8              0.39        0.65
# 9             -0.44        0.31
# 10            -0.69       -0.23
# 11            -0.46       -0.56
# 12             0.07        0.15

# %%
ttdn.head(13)
# Out:
#      Stt            Điện lực  KH 2025  Lũy kế 6T/2024  Lũy kế 6T/2025  \
# 0    1.0     Điện Lực Đà Lạt     1.21            1.31            1.14
# 1    2.0    Điện Lực Bảo Lộc     1.70            1.74            1.57
# 2    3.0  Điện Lực Đơn Dương     1.61            1.65            1.63
# 3    4.0    Điện Lực Di Linh     1.48            1.53            2.42
# 4    5.0  Điện Lực Đức Trọng     1.59            1.55            1.76
# 5    6.0     Điện Lực Lâm Hà     1.57            1.63            2.00
# 6    7.0   Điện lực Đạ Huoai     2.84            2.89            2.88
# 7    8.0     Điện lực Đạ Tẻh     1.26            1.20            1.68
# 8    9.0   Điện Lực Cát Tiên     1.18            1.44            1.83
# 9   10.0    Điện Lực Bảo Lâm     1.55            2.30            1.86
# 10  11.0  Điện Lực Lạc Dương     1.29            1.75            1.06
# 11  12.0   Điện Lực Đam Rông     2.02            1.92            1.46
# 12   NaN           Tổng cộng     1.60            1.68            1.75
#
#     So sánh cùng kỳ  So sánh KH
# 0             -0.17       -0.07
# 1             -0.17       -0.13
# 2             -0.02        0.02
# 3              0.89        0.94
# 4              0.21        0.17
# 5              0.37        0.43
# 6             -0.01        0.04
# 7              0.48        0.42
# 8              0.39        0.65
# 9             -0.44        0.31
# 10            -0.69       -0.23
# 11            -0.46       -0.56
# 12             0.07        0.15

# %%
ttdn.shape
# Out:
# (13, 7)

# %%
solieu1 = pd.DataFrame(ttdn, columns=['Điện lực', 'So sánh cùng kỳ'])

# Bỏ dòng "Tổng cộng"
solieux = solieu1[solieu1['Điện lực'] != 'Tổng cộng'].copy()

print(solieux)

# Làm tròn
solieux['So sánh cùng kỳ'] = solieux['So sánh cùng kỳ'].round(2)

# Nhóm tăng/giảm
giamx = solieux[solieux['So sánh cùng kỳ'] < 0]
tangx = solieux[solieux['So sánh cùng kỳ'] > 0]

# Mô tả từng nhóm
giam_str1 = ', '.join([f"{row['Điện lực']} ({row['So sánh cùng kỳ']:.2f})" for _, row in giamx.iterrows()])
tang_str1 = ', '.join([f"{row['Điện lực']} ({row['So sánh cùng kỳ']:.2f})" for _, row in tangx.iterrows()])

# Ghép mô tả đầy đủ
ket_qua_1 = f"""Tổn thất giảm so với cùng kỳ gồm: {giam_str1}.
Tổn thất tăng so với cùng kỳ gồm: {tang_str1}."""

print(ket_qua_1)
# Out:
#               Điện lực  So sánh cùng kỳ
# 0      Điện Lực Đà Lạt            -0.17
# 1     Điện Lực Bảo Lộc            -0.17
# 2   Điện Lực Đơn Dương            -0.02
# 3     Điện Lực Di Linh             0.89
# 4   Điện Lực Đức Trọng             0.21
# 5      Điện Lực Lâm Hà             0.37
# 6    Điện lực Đạ Huoai            -0.01
# 7      Điện lực Đạ Tẻh             0.48
# 8    Điện Lực Cát Tiên             0.39
# 9     Điện Lực Bảo Lâm            -0.44
# 10  Điện Lực Lạc Dương            -0.69
# 11   Điện Lực Đam Rông            -0.46
# Tổn thất giảm so với cùng kỳ gồm: Điện Lực Đà Lạt (-0.17), Điện Lực Bảo Lộc (-0.17), Điện Lực Đơn Dương (-0.02), Điện lực Đạ Huoai (-0.01), Điện Lực Bảo Lâm (-0.44), Điện Lực Lạc Dương (-0.69), Điện Lực Đam Rông (-0.46).
# Tổn thất tăng so với cùng kỳ gồm: Điện Lực Di Linh (0.89), Điện Lực Đức Trọng (0.21), Điện Lực Lâm Hà (0.37), Điện lực Đạ Tẻh (0.48), Điện Lực Cát Tiên (0.39).

# %%
solieu2 = pd.DataFrame(ttdn, columns=['Điện lực', 'So sánh KH'])
#print(solieu2)

solieuy = solieu2[solieu2['Điện lực'] != 'Tổng cộng'].copy()

print(solieuy)

# Làm tròn
solieuy['So sánh KH'] = solieuy['So sánh KH'].round(2)

# Nhóm tăng/giảm
giamy = solieuy[solieuy['So sánh KH'] < 0]
tangy = solieuy[solieuy['So sánh KH'] > 0]

# Mô tả từng nhóm
giam_str2 = ', '.join([f"{row['Điện lực']} ({row['So sánh KH']:.2f})" for _, row in giamy.iterrows()])
tang_str2 = ', '.join([f"{row['Điện lực']} ({row['So sánh KH']:.2f})" for _, row in tangy.iterrows()])

# Ghép mô tả đầy đủ
ket_qua_2 = f"""Tổn thất giảm so với cùng kỳ gồm: {giam_str2}. Tổn thất tăng so với cùng kỳ gồm: {tang_str2}."""

print(ket_qua_2)
# Out:
#               Điện lực  So sánh KH
# 0      Điện Lực Đà Lạt       -0.07
# 1     Điện Lực Bảo Lộc       -0.13
# 2   Điện Lực Đơn Dương        0.02
# 3     Điện Lực Di Linh        0.94
# 4   Điện Lực Đức Trọng        0.17
# 5      Điện Lực Lâm Hà        0.43
# 6    Điện lực Đạ Huoai        0.04
# 7      Điện lực Đạ Tẻh        0.42
# 8    Điện Lực Cát Tiên        0.65
# 9     Điện Lực Bảo Lâm        0.31
# 10  Điện Lực Lạc Dương       -0.23
# 11   Điện Lực Đam Rông       -0.56
# Tổn thất giảm so với cùng kỳ gồm: Điện Lực Đà Lạt (-0.07), Điện Lực Bảo Lộc (-0.13), Điện Lực Lạc Dương (-0.23), Điện Lực Đam Rông (-0.56). Tổn thất tăng so với cùng kỳ gồm: Điện Lực Đơn Dương (0.02), Điện Lực Di Linh (0.94), Điện Lực Đức Trọng (0.17), Điện Lực Lâm Hà (0.43), Điện lực Đạ Huoai (0.04), Điện lực Đạ Tẻh (0.42), Điện Lực Cát Tiên (0.65), Điện Lực Bảo Lâm (0.31).

# %%
#
